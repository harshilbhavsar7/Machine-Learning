# %%
from keras.models import load_model
from keras.preprocessing import image
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-b6b63438244c> in <module>
# ----> 1 from keras.models import load_model
#       2 from keras.preprocessing import image
#       3 import numpy as np
#       4 import cv2
#       5 import matplotlib.pyplot as plt
#
# ~\Anaconda3\envs\tensorflow_cpu\lib\site-packages\keras\__init__.py in <module>
#       3 from . import utils
#       4 from . import activations
# ----> 5 from . import applications
#       6 from . import backend
#       7 from . import datasets
#
# ~\Anaconda3\envs\tensorflow_cpu\lib\site-packages\keras\applications\__init__.py in <module>
#      11 import keras_applications
#      12
# ---> 13 keras_applications.set_keras_submodules(
#      14     backend=backend,
#      15     engine=engine,
#
# AttributeError: module 'keras_applications' has no attribute 'set_keras_submodules'

# %%
model=load_model('Beer_Cherry.h5')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e17bed306522> in <module>
# ----> 1 model=load_model('Beer_Cherry.h5')
#
# NameError: name 'load_model' is not defined

# %%
def classifier(path):
    raw_img=image.load_img(path,target_size=(150,150))#converting image to target size
    raw_img=image.img_to_array(raw_img)#convert image to array
    raw_img=np.expand_dims(raw_img,axis=0)#expand dimensions
    raw_img=raw_img/255
    prediction=model.predict_classes(raw_img)[0][0]
    accuracy = model.predict(raw_img)[0][0]
    plt.imshow(cv2.imread(path))
    print('Accuracy ',accuracy)
    if prediction:
        print("It's a Pepsi ")
    else:
        print("It's a Beer ")

# %%
classifier(r'C:\Users\Harshil\Desktop\mugbeer.jfif')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-1859be352183> in <module>
# ----> 1 classifier(r'C:\Users\Harshil\Desktop\mugbeer.jfif')
#
# <ipython-input-3-c0e128faa9ca> in classifier(path)
#       1 def classifier(path):
# ----> 2     raw_img=image.load_img(path,target_size=(150,150))#converting image to target size
#       3     raw_img=image.img_to_array(raw_img)#convert image to array
#       4     raw_img=np.expand_dims(raw_img,axis=0)#expand dimensions
#       5     raw_img=raw_img/255
#
# NameError: name 'image' is not defined

# %%
classifier(r'C:\Users\Harshil\Desktop\Pepsi.jpg')
# Out:
# Accuracy  1.0
# It's a Pepsi

# %%
classifier(r'C:\Users\Harshil\Desktop\beer.jpg')
# Out:
# Accuracy  0.0068407734
# It's a Beer
